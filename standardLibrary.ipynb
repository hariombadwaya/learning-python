# %%
import array
arr = array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
# Out:
# 6
# cherry

# %%
# Out:
# 9
# banana

# %%
#random
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 3
# apple

# %%
# file and directory access
import os
print(os.getcwd())
# Out:
# c:\Users\Lenovo Laptop\OneDrive\Desktop\python

# %%
os.mkdir("test_dir")

# %%
# High level operations on files and  collection of files
import shutil
shutil.copyfile('src.txt','destination.txt')

# %%
# Data serialization
import json
data= {'name': 'hari', 'age': 23}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "hari", "age": 23}
# <class 'str'>
# {'name': 'hari', 'age': 23}
# <class 'dict'>

# %%
#csv
import csv

with open('example.csv',mode='w',newline='') as file:
    writer= csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Krish',23])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '23']

# %%
#datetime
from datetime import datetime,timedelta

now= datetime.now()
print(now)

yesterday = now- timedelta(days=1)
print(yesterday)
# Out:
# 2026-08-25 22:31:52.808139
# 2026-08-24 22:31:52.808139

# %%
# time
import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1787678326.3383138
# 1787678328.3387997

# %%
#Regular expresion
import re
pattern = r'\d+'
text='There are 123 apples 456'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
