# %% [markdown]
# Stemming is the process of reducing a word to its base/root-like form by removing prefixes or suffixes.
#
# The important thing is that the result does not necessarily have to be a real English word.
#
# Simple example
# playing   → play
# played    → play
# plays     → play
# player    → player

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
words = ["eating", "eats", "eaten","writing","writes","programming","programs", "programers", "history"]

# %%
for word in words:
    print(word+ "---->"+stemming.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# programers---->program
# history---->histori

# %%
stemming.stem("congratulations")
# Out:
# 'congratul'

# %%
stemming.stem('setting')
# Out:
# 'set'

# %%
# LAncaster Stemming algorithm
from nltk.stem import LancasterStemmer

# %%
lancaster  = LancasterStemmer()
for word in words:
    print(word+ "---->"+lancaster.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eat
# writing---->writ
# writes---->writ
# programming---->program
# programs---->program
# programers---->program
# history---->hist

# %% [markdown]
# RegexpStemmer class
# NLTK has RegexpStemmer class with the help of which we can easily implement Rgurlar Expression Stemmer algorithms. it basically takes a single regular expression and remove any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$',min=4)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("ingplaying")
# Out:
# 'ingplay'

# %%
#Snowballstemmer 

from nltk.stem import SnowballStemmer

# %%
snowballstemmer = SnowballStemmer('english',ignore_stopwords=False)

# %%
for word in words:
    print(word+ "---->"+snowballstemmer.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# programers---->program
# history---->histori

# %%
print(snowballstemmer.stem("fairly"))
print(snowballstemmer.stem("sportingly"))
# Out:
# fair
# sport

# %% [markdown]
# Wordnet Lemmatizer
# Lemmatization technique is like stemming. The output we well get after lemmatization is called 'lemma' which is a root wordd rather than root stem, the output of stemming, after lemmatization, we will be getting a valid word that means the same thing.
#
# NLTK provides WordnetLemmaitzer class which is a thin wrapper around the wordnet corpus, this class uses morphy() function to the Wordnet CorpusReader class to find a lemma. let us understand it with an example -

# %%
import nltk 
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import nltk
#       2 from nltk.stem import WordNetLemmatizer
#       3 lemmatizer = WordNetLemmatizer()
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Lenovo
# [nltk_data]     Laptop\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Lenovo
# [nltk_data]     Laptop\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
'''
POS - noun n
verb - v
adjective - a
adverb - a
'''
for word in words:
    print(word+ "---->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       3 verb - v
#       4 adjective - a
#       5 adverb - a
#       6 '''
# ----> 7 for word in words:
#       8     print(word+ "---->"+lemmatizer.lemmatize(word,pos='v'))
#
# NameError: name 'words' is not defined

# %%
print(lemmatizer.lemmatize("got",pos="v"))
# Out:
# get

# %%
print(lemmatizer.lemmatize("took",pos='v'))
# Out:
# take

# %%
import nltk 
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("went", pos = 'v'))
# Out:
# go

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Lenovo Laptop\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# 'c:\Users\Lenovo' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk 
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("goes", pos = 'v'))
# Out:
# go
